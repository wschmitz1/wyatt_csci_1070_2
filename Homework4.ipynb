# %%
import numpy as np
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
data_df = pd.read_csv("CSCI_1070_survey_results.csv")
data_df.head()
# Out:
#                     Timestamp What is your name?  \
# 0   2024/01/29 6:34:23 PM CST      Gavin Edwards
# 1   2024/01/29 6:46:07 PM CST                NaN
# 2   2024/01/29 7:45:39 PM CST        Connor Love
# 3   2024/01/29 7:47:12 PM CST               Liam
# 4  2024/01/29 10:45:38 PM CST  Aarushi Choudhary
#
#   What state/country were you born in? Are you working while in school?  \
# 0                             Missouri                              Yes
# 1                Saint Louis, Missouri                              Yes
# 2                             Illinois                               No
# 3                             Missouri                              Yes
# 4                                Japan                              Yes
#
#   How much experience do you have programming? What class are you in?   \
# 0                            6 months - 1 year                Freshman
# 1                                   0-3 months                Freshman
# 2                                   0-3 months                Freshman
# 3                                   0-3 months                Freshman
# 4                                   0-3 months                Freshman
#
#   How many siblings do you have?  \
# 0                              1
# 1                              2
# 2                              1
# 3                              1
# 4                              1
#
#         How many pets and of which kind do you have?  \
# 0              I have two dogs both chihuahua mixes.
# 1                                                  0
# 2  I have two golden retrievers, Ellie and Amber....
# 3                                                  0
# 4                                            No pets
#
#   What is your favorite type of food? Where do you live?  \
# 0   Pasta but fish is a close second.          On campus
# 1                           Hot wings         Off campus
# 2                            Mexican.          On campus
# 3                          Vietnamese         Off campus
# 4                               Pasta          On campus
#
#   Do you take the metro?     What is your major? How old are you?  \
# 0                     No           Data Science                18
# 1                     No                 Nursing               19
# 2                     No  Economics and Finance.               19
# 3                     No            Biochemistry               18
# 4                    Yes         Health Sciences               18
#
#   What is your favorite TV show? What is your favorite video game?  \
# 0                   Breaking Bad                     Rocket League
# 1                 Criminal Minds                          Valorant
# 2                      The Wire.                  Pokémon White 2.
# 3                            NaN                               NaN
# 4                            NaN                       Spiderman 2
#
#           What is your favorite book?  \
# 0                   The Scythe series
# 1    A Little life by Hanya Yanaghara
# 2  "Surprised by Joy" by C. S. Lewis.
# 3                                 NaN
# 4                                 NaN
#
#                      Why are you taking this class?   \
# 0      Its a requirement for the data science major.
# 1  I have an interest in programming. I enjoy lea...
# 2  Transfer course requirements for the Universit...
# 3                                      Applicability
# 4          I'm trying to get a minor in data science
#
#     Whats your favorite bash command?
# 0                                  ls
# 1                                 NaN
# 2  <git push> by far, too satisfying.
# 3                                 NaN
# 4                                  ls

# %%
data_df.dtypes
# Out:
# Timestamp                                       object
# What is your name?                              object
# What state/country were you born in?            object
# Are you working while in school?                object
# How much experience do you have programming?    object
# What class are you in?                          object
# How many siblings do you have?                  object
# How many pets and of which kind do you have?    object
# What is your favorite type of food?             object
# Where do you live?                              object
# Do you take the metro?                          object
# What is your major?                             object
# How old are you?                                object
# What is your favorite TV show?                  object
# What is your favorite video game?               object
# What is your favorite book?                     object
# Why are you taking this class?                  object
# Whats your favorite bash command?               object
# dtype: object

# %%
data_df.columns = data_df.columns.str.replace(" ","_")

# %%
data_df.head(21)
# Out:
#                      Timestamp   What_is_your_name?  \
# 0    2024/01/29 6:34:23 PM CST        Gavin Edwards
# 1    2024/01/29 6:46:07 PM CST                  NaN
# 2    2024/01/29 7:45:39 PM CST          Connor Love
# 3    2024/01/29 7:47:12 PM CST                 Liam
# 4   2024/01/29 10:45:38 PM CST    Aarushi Choudhary
# 5   2024/01/29 10:55:40 PM CST           Noel Zerai
# 6   2024/01/29 11:50:50 PM CST           Kine Thiam
# 7    2024/01/30 5:24:37 PM CST      Bandar Aldhahri
# 8   2024/01/31 10:44:53 AM CST             Aida Bah
# 9    2024/01/31 6:34:07 PM CST          Kevin Patel
# 10   2024/01/31 7:18:31 PM CST          Brady Loehr
# 11   2024/01/31 7:19:58 PM CST        Wyatt Schmitz
# 12   2024/01/31 7:20:10 PM CST          Alec Arnold
# 13   2024/01/31 7:20:54 PM CST          Tori Willis
# 14   2024/01/31 7:21:43 PM CST      Giovanni Loftis
# 15   2024/01/31 7:22:36 PM CST     Nithya Bollineni
# 16   2024/01/31 7:22:58 PM CST  Jacob Montes-Sabino
# 17   2024/01/31 7:23:13 PM CST        Will Naftzger
# 18   2024/01/31 7:25:03 PM CST        Nora El-Ruwie
# 19   2024/01/31 7:25:54 PM CST        Darryl Franks
#
#    What_state/country_were_you_born_in? Are_you_working_while_in_school?  \
# 0                              Missouri                              Yes
# 1                 Saint Louis, Missouri                              Yes
# 2                              Illinois                               No
# 3                              Missouri                              Yes
# 4                                 Japan                              Yes
# 5                              Missouri                              Yes
# 6                         United States                              Yes
# 7                          Saudi Arabia                              Yes
# 8                             Minnesota                              Yes
# 9                                 India                               No
# 10                             Missouri                               No
# 11                           New Mexico                              Yes
# 12              United States, Missouri                               No
# 13                             Missouri                              Yes
# 14                             Missouri                              Yes
# 15                         Missouri/U.S                               No
# 16                         Georgia, USA                               No
# 17                             Illinois                              Yes
# 18                      Benghazi, Libya                              Yes
# 19                             Missouri                               No
#
#    How_much_experience_do_you_have_programming? What_class_are_you_in?_  \
# 0                             6 months - 1 year                Freshman
# 1                                    0-3 months                Freshman
# 2                                    0-3 months                Freshman
# 3                                    0-3 months                Freshman
# 4                                    0-3 months                Freshman
# 5                                    0-3 months                Freshman
# 6                                    0-3 months                Freshman
# 7                                    0-3 months                  Junior
# 8                                    0-3 months                Freshman
# 9                                    0-3 months                  Senior
# 10                                   0-3 months               Sophomore
# 11                                   0-3 months                Freshman
# 12                                   4-6 months                Freshman
# 13                                    1-2 years               Sophomore
# 14                                   0-3 months               Sophomore
# 15                                   0-3 months                Freshman
# 16                                   0-3 months                  Junior
# 17                                   0-3 months               Sophomore
# 18                                   0-3 months                Freshman
# 19                            6 months - 1 year                Freshman
#
#    How_many_siblings_do_you_have?  \
# 0                               1
# 1                               2
# 2                               1
# 3                               1
# 4                               1
# 5                               2
# 6                              5+
# 7                              5+
# 8                               2
# 9                               0
# 10                              1
# 11                              1
# 12                              1
# 13                             5+
# 14                              4
# 15                              1
# 16                              2
# 17                              2
# 18                              3
# 19                              2
#
#          How_many_pets_and_of_which_kind_do_you_have?  \
# 0               I have two dogs both chihuahua mixes.
# 1                                                   0
# 2   I have two golden retrievers, Ellie and Amber....
# 3                                                   0
# 4                                             No pets
# 5                                                none
# 6                                                   0
# 7                                                   0
# 8                                                   0
# 9                                                 NaN
# 10                     We have a Husky named Maverick
# 11                                            None ):
# 12                          2 miniature daschund dogs
# 13                                               none
# 14                                         1 Maincoon
# 15                                                NaN
# 16                                                  0
# 17  My french bulldog just passed away a few month...
# 18                                  2 cats and 1 dog
# 19                                           No pets
#
#             What_is_your_favorite_type_of_food? Where_do_you_live?  \
# 0             Pasta but fish is a close second.          On campus
# 1                                     Hot wings         Off campus
# 2                                      Mexican.          On campus
# 3                                    Vietnamese         Off campus
# 4                                         Pasta          On campus
# 5                                        injera          On campus
# 6                                     PASTAAAAA          On campus
# 7                                        Kabsa          Off campus
# 8                                  Gambian Food          On campus
# 9                                       Italian         Off campus
# 10  some sort of steak, probably a filet mignon          On campus
# 11                        Burgers (blue cheese)         Off campus
# 12                              grilled chicken          On campus
# 13                                        pasta         Off campus
# 14                                       salmon         Off campus
# 15                      I don't have a favorite          On campus
# 16                                        Pasta         Off campus
# 17                         mexican/middleastern          On campus
# 18                                     Brownies         Off campus
# 19                               Pizza or Steak          On campus
#
#    Do_you_take_the_metro?                                What_is_your_major?  \
# 0                      No                                      Data Science
# 1                      No                                            Nursing
# 2                      No                             Economics and Finance.
# 3                      No                                       Biochemistry
# 4                     Yes                                    Health Sciences
# 5                      No                                           comp sci
# 6                     Yes  It was pre medicine therefore biology but I de...
# 7                      No  Criminology and Criminal Justice and I am plan...
# 8                     Yes                                   Computer Science
# 9                      No                                            Finance
# 10                     No                                        Mathematics
# 11                     No                 International Business (Graduated)
# 12                     No                                   computer science
# 13                     No                                   Computer Science
# 14                     No                                       data science
# 15                     No                                   Forensic Science
# 16                     No                                   Computer Science
# 17                    Yes                                       Data Science
# 18                     No                                  Computer Science
# 19                     No                                       Computer Sci
#
#                 How_old_are_you?  \
# 0                             18
# 1                             19
# 2                             19
# 3                             18
# 4                             18
# 5                             19
# 6                             18
# 7                            NaN
# 8                             18
# 9                             21
# 10  19 turning 20 on February 28
# 11                            22
# 12                            18
# 13                            19
# 14                            20
# 15                            18
# 16                            21
# 17                            19
# 18                            18
# 19                  18 years old
#
#                        What_is_your_favorite_TV_show?  \
# 0                                        Breaking Bad
# 1                                      Criminal Minds
# 2                                           The Wire.
# 3                                                 NaN
# 4                                                 NaN
# 5                                         on my block
# 6                                               Reign
# 7                                        Breaking Bad
# 8                                                 NaN
# 9                                      Peaky Blinders
# 10  all time: How to Get Away with Murder. still r...
# 11                                  Better Call Saul
# 12                                       black mirror
# 13                              Nothing at the moment
# 14                                            Atlanta
# 15                                     I can't choose
# 16                              How I Met Your Mother
# 17                                       Breaking Bad
# 18                                             Reign
# 19                                The Vampire Diaries
#
#    What_is_your_favorite_video_game?  \
# 0                      Rocket League
# 1                           Valorant
# 2                   Pokémon White 2.
# 3                                NaN
# 4                        Spiderman 2
# 5            assassins creed origins
# 6                       It takes two
# 7                     FIFA - Soccer
# 8                                NaN
# 9                            Warzone
# 10                  currently Madden
# 11               Super Mario Galaxy
# 12                          valorant
# 13                       Predecessor
# 14                 fallout new Vegas
# 15                          Fortnite
# 16                              FIFA
# 17                        The Finals
# 18                          The Sims
# 19                   Any Nba 2k game
#
#                           What_is_your_favorite_book?  \
# 0                                   The Scythe series
# 1                    A Little life by Hanya Yanaghara
# 2                  "Surprised by Joy" by C. S. Lewis.
# 3                                                 NaN
# 4                                                 NaN
# 5                                         kite runner
# 6                                              Wonder
# 7                                                 NaN
# 8                Dead End Memories - Banana Yoshimoto
# 9                                    The Great Gatsby
# 10  haven't read for fun in years but the I am Num...
# 11                        The Man in the High Castle
# 12                                            catch22
# 13                              Nothing at the moment
# 14                                           catch 22
# 15                             Karen M. McManus books
# 16              Harry Potter and the Sorcerer's Stone
# 17                                               Wool
# 18        The Throne of Glass series by Sarah J. Maas
# 19                  Percy Jackson the lighting thief
#
#                       Why_are_you_taking_this_class?_  \
# 0       Its a requirement for the data science major.
# 1   I have an interest in programming. I enjoy lea...
# 2   Transfer course requirements for the Universit...
# 3                                       Applicability
# 4           I'm trying to get a minor in data science
# 5              just as an intro to my desired career.
# 6   At first it was to see if I’d like computer sc...
# 7   I am planing to get a master degree in CyberSe...
# 8                      For my major, to learn python
# 9   To learn the basics of python to help me stand...
# 10                     data science minor requirement
# 11  Foundation in Computer Science. I want to expa...
# 12                                   credit for major
# 13                  I want to be a better programmer.
# 14                                           required
# 15  For my minor and as a backup for a potential c...
# 16                                  Major requirement
# 17                         I need it for data science
# 18  To start building a foundation in code, especi...
# 19  I want to be able to do my major. Started of w...
#
#                     Whats_your_favorite_bash_command?
# 0                                                  ls
# 1                                                 NaN
# 2                  <git push> by far, too satisfying.
# 3                                                 NaN
# 4                                                  ls
# 5                                                ls
# 6                                                 NaN
# 7                                   until  now is pwd
# 8                                                tree
# 9                                                'cd'
# 10                                   jupyter notebook
# 11                                                NaN
# 12                                   jupyter notebook
# 13                                                 cd
# 14                                              mkdir
# 15                                                 ls
# 16                                                NaN
# 17                                                 cd
# 18  ls, it's been the most useful command so far a...
# 19                                 Don't have one yet

# %%
data_df['What_state/country_were_you_born_in?'].mask(data_df['What_state/country_were_you_born_in?'] == 'Missouri', 'Missouri, USA', inplace=True)
data_df['What_state/country_were_you_born_in?'].mask(data_df['What_state/country_were_you_born_in?'] == 'Illinois', 'Illinois, USA', inplace=True)
data_df['What_state/country_were_you_born_in?'].mask(data_df['What_state/country_were_you_born_in?'] == 'Saint Louis, Missouri', 'Missouri, USA', inplace=True)
data_df['What_state/country_were_you_born_in?'].mask(data_df['What_state/country_were_you_born_in?'] == 'New Mexico', 'New Mexico, USA', inplace=True)
data_df['What_state/country_were_you_born_in?'].mask(data_df['What_state/country_were_you_born_in?'] == 'Missouri/U.S', 'Missouri, USA', inplace=True)
data_df['What_state/country_were_you_born_in?'].mask(data_df['What_state/country_were_you_born_in?'] == 'Minnesota', 'Minnesota, USA', inplace=True)
data_df['What_state/country_were_you_born_in?'].mask(data_df['What_state/country_were_you_born_in?'] == 'United States, Missouri', 'Missouri, USA', inplace=True)

data_df.head(22)
# Out:
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3988705725.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_state/country_were_you_born_in?'].mask(data_df['What_state/country_were_you_born_in?'] == 'Missouri', 'Missouri, USA', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3988705725.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_state/country_were_you_born_in?'].mask(data_df['What_state/country_were_you_born_in?'] == 'Illinois', 'Illinois, USA', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3988705725.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_state/country_were_you_born_in?'].mask(data_df['What_state/country_were_you_born_in?'] == 'Saint Louis, Missouri', 'Missouri, USA', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3988705725.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_state/country_were_you_born_in?'].mask(data_df['What_state/country_were_you_born_in?'] == 'New Mexico', 'New Mexico, USA', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3988705725.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_state/country_were_you_born_in?'].mask(data_df['What_state/country_were_you_born_in?'] == 'Missouri/U.S', 'Missouri, USA', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3988705725.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_state/country_were_you_born_in?'].mask(data_df['What_state/country_were_you_born_in?'] == 'Minnesota', 'Minnesota, USA', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3988705725.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_state/country_were_you_born_in?'].mask(data_df['What_state/country_were_you_born_in?'] == 'United States, Missouri', 'Missouri, USA', inplace=True)
#                      Timestamp   What_is_your_name?  \
# 0    2024/01/29 6:34:23 PM CST        Gavin Edwards
# 1    2024/01/29 6:46:07 PM CST                  NaN
# 2    2024/01/29 7:45:39 PM CST          Connor Love
# 3    2024/01/29 7:47:12 PM CST                 Liam
# 4   2024/01/29 10:45:38 PM CST    Aarushi Choudhary
# 5   2024/01/29 10:55:40 PM CST           Noel Zerai
# 6   2024/01/29 11:50:50 PM CST           Kine Thiam
# 7    2024/01/30 5:24:37 PM CST      Bandar Aldhahri
# 8   2024/01/31 10:44:53 AM CST             Aida Bah
# 9    2024/01/31 6:34:07 PM CST          Kevin Patel
# 10   2024/01/31 7:18:31 PM CST          Brady Loehr
# 11   2024/01/31 7:19:58 PM CST        Wyatt Schmitz
# 12   2024/01/31 7:20:10 PM CST          Alec Arnold
# 13   2024/01/31 7:20:54 PM CST          Tori Willis
# 14   2024/01/31 7:21:43 PM CST      Giovanni Loftis
# 15   2024/01/31 7:22:36 PM CST     Nithya Bollineni
# 16   2024/01/31 7:22:58 PM CST  Jacob Montes-Sabino
# 17   2024/01/31 7:23:13 PM CST        Will Naftzger
# 18   2024/01/31 7:25:03 PM CST        Nora El-Ruwie
# 19   2024/01/31 7:25:54 PM CST        Darryl Franks
#
#    What_state/country_were_you_born_in? Are_you_working_while_in_school?  \
# 0                         Missouri, USA                              Yes
# 1                         Missouri, USA                              Yes
# 2                         Illinois, USA                               No
# 3                         Missouri, USA                              Yes
# 4                                 Japan                              Yes
# 5                         Missouri, USA                              Yes
# 6                         United States                              Yes
# 7                          Saudi Arabia                              Yes
# 8                        Minnesota, USA                              Yes
# 9                                 India                               No
# 10                        Missouri, USA                               No
# 11                      New Mexico, USA                              Yes
# 12                        Missouri, USA                               No
# 13                        Missouri, USA                              Yes
# 14                        Missouri, USA                              Yes
# 15                        Missouri, USA                               No
# 16                         Georgia, USA                               No
# 17                        Illinois, USA                              Yes
# 18                      Benghazi, Libya                              Yes
# 19                        Missouri, USA                               No
#
#    How_much_experience_do_you_have_programming? What_class_are_you_in?_  \
# 0                             6 months - 1 year                Freshman
# 1                                    0-3 months                Freshman
# 2                                    0-3 months                Freshman
# 3                                    0-3 months                Freshman
# 4                                    0-3 months                Freshman
# 5                                    0-3 months                Freshman
# 6                                    0-3 months                Freshman
# 7                                    0-3 months                  Junior
# 8                                    0-3 months                Freshman
# 9                                    0-3 months                  Senior
# 10                                   0-3 months               Sophomore
# 11                                   0-3 months                Freshman
# 12                                   4-6 months                Freshman
# 13                                    1-2 years               Sophomore
# 14                                   0-3 months               Sophomore
# 15                                   0-3 months                Freshman
# 16                                   0-3 months                  Junior
# 17                                   0-3 months               Sophomore
# 18                                   0-3 months                Freshman
# 19                            6 months - 1 year                Freshman
#
#    How_many_siblings_do_you_have?  \
# 0                               1
# 1                               2
# 2                               1
# 3                               1
# 4                               1
# 5                               2
# 6                              5+
# 7                              5+
# 8                               2
# 9                               0
# 10                              1
# 11                              1
# 12                              1
# 13                             5+
# 14                              4
# 15                              1
# 16                              2
# 17                              2
# 18                              3
# 19                              2
#
#          How_many_pets_and_of_which_kind_do_you_have?  \
# 0               I have two dogs both chihuahua mixes.
# 1                                                   0
# 2   I have two golden retrievers, Ellie and Amber....
# 3                                                   0
# 4                                             No pets
# 5                                                none
# 6                                                   0
# 7                                                   0
# 8                                                   0
# 9                                                 NaN
# 10                     We have a Husky named Maverick
# 11                                            None ):
# 12                          2 miniature daschund dogs
# 13                                               none
# 14                                         1 Maincoon
# 15                                                NaN
# 16                                                  0
# 17  My french bulldog just passed away a few month...
# 18                                  2 cats and 1 dog
# 19                                           No pets
#
#             What_is_your_favorite_type_of_food? Where_do_you_live?  \
# 0             Pasta but fish is a close second.          On campus
# 1                                     Hot wings         Off campus
# 2                                      Mexican.          On campus
# 3                                    Vietnamese         Off campus
# 4                                         Pasta          On campus
# 5                                        injera          On campus
# 6                                     PASTAAAAA          On campus
# 7                                        Kabsa          Off campus
# 8                                  Gambian Food          On campus
# 9                                       Italian         Off campus
# 10  some sort of steak, probably a filet mignon          On campus
# 11                        Burgers (blue cheese)         Off campus
# 12                              grilled chicken          On campus
# 13                                        pasta         Off campus
# 14                                       salmon         Off campus
# 15                      I don't have a favorite          On campus
# 16                                        Pasta         Off campus
# 17                         mexican/middleastern          On campus
# 18                                     Brownies         Off campus
# 19                               Pizza or Steak          On campus
#
#    Do_you_take_the_metro?                                What_is_your_major?  \
# 0                      No                                      Data Science
# 1                      No                                            Nursing
# 2                      No                             Economics and Finance.
# 3                      No                                       Biochemistry
# 4                     Yes                                    Health Sciences
# 5                      No                                           comp sci
# 6                     Yes  It was pre medicine therefore biology but I de...
# 7                      No  Criminology and Criminal Justice and I am plan...
# 8                     Yes                                   Computer Science
# 9                      No                                            Finance
# 10                     No                                        Mathematics
# 11                     No                 International Business (Graduated)
# 12                     No                                   computer science
# 13                     No                                   Computer Science
# 14                     No                                       data science
# 15                     No                                   Forensic Science
# 16                     No                                   Computer Science
# 17                    Yes                                       Data Science
# 18                     No                                  Computer Science
# 19                     No                                       Computer Sci
#
#                 How_old_are_you?  \
# 0                             18
# 1                             19
# 2                             19
# 3                             18
# 4                             18
# 5                             19
# 6                             18
# 7                            NaN
# 8                             18
# 9                             21
# 10  19 turning 20 on February 28
# 11                            22
# 12                            18
# 13                            19
# 14                            20
# 15                            18
# 16                            21
# 17                            19
# 18                            18
# 19                  18 years old
#
#                        What_is_your_favorite_TV_show?  \
# 0                                        Breaking Bad
# 1                                      Criminal Minds
# 2                                           The Wire.
# 3                                                 NaN
# 4                                                 NaN
# 5                                         on my block
# 6                                               Reign
# 7                                        Breaking Bad
# 8                                                 NaN
# 9                                      Peaky Blinders
# 10  all time: How to Get Away with Murder. still r...
# 11                                  Better Call Saul
# 12                                       black mirror
# 13                              Nothing at the moment
# 14                                            Atlanta
# 15                                     I can't choose
# 16                              How I Met Your Mother
# 17                                       Breaking Bad
# 18                                             Reign
# 19                                The Vampire Diaries
#
#    What_is_your_favorite_video_game?  \
# 0                      Rocket League
# 1                           Valorant
# 2                   Pokémon White 2.
# 3                                NaN
# 4                        Spiderman 2
# 5            assassins creed origins
# 6                       It takes two
# 7                     FIFA - Soccer
# 8                                NaN
# 9                            Warzone
# 10                  currently Madden
# 11               Super Mario Galaxy
# 12                          valorant
# 13                       Predecessor
# 14                 fallout new Vegas
# 15                          Fortnite
# 16                              FIFA
# 17                        The Finals
# 18                          The Sims
# 19                   Any Nba 2k game
#
#                           What_is_your_favorite_book?  \
# 0                                   The Scythe series
# 1                    A Little life by Hanya Yanaghara
# 2                  "Surprised by Joy" by C. S. Lewis.
# 3                                                 NaN
# 4                                                 NaN
# 5                                         kite runner
# 6                                              Wonder
# 7                                                 NaN
# 8                Dead End Memories - Banana Yoshimoto
# 9                                    The Great Gatsby
# 10  haven't read for fun in years but the I am Num...
# 11                        The Man in the High Castle
# 12                                            catch22
# 13                              Nothing at the moment
# 14                                           catch 22
# 15                             Karen M. McManus books
# 16              Harry Potter and the Sorcerer's Stone
# 17                                               Wool
# 18        The Throne of Glass series by Sarah J. Maas
# 19                  Percy Jackson the lighting thief
#
#                       Why_are_you_taking_this_class?_  \
# 0       Its a requirement for the data science major.
# 1   I have an interest in programming. I enjoy lea...
# 2   Transfer course requirements for the Universit...
# 3                                       Applicability
# 4           I'm trying to get a minor in data science
# 5              just as an intro to my desired career.
# 6   At first it was to see if I’d like computer sc...
# 7   I am planing to get a master degree in CyberSe...
# 8                      For my major, to learn python
# 9   To learn the basics of python to help me stand...
# 10                     data science minor requirement
# 11  Foundation in Computer Science. I want to expa...
# 12                                   credit for major
# 13                  I want to be a better programmer.
# 14                                           required
# 15  For my minor and as a backup for a potential c...
# 16                                  Major requirement
# 17                         I need it for data science
# 18  To start building a foundation in code, especi...
# 19  I want to be able to do my major. Started of w...
#
#                     Whats_your_favorite_bash_command?
# 0                                                  ls
# 1                                                 NaN
# 2                  <git push> by far, too satisfying.
# 3                                                 NaN
# 4                                                  ls
# 5                                                ls
# 6                                                 NaN
# 7                                   until  now is pwd
# 8                                                tree
# 9                                                'cd'
# 10                                   jupyter notebook
# 11                                                NaN
# 12                                   jupyter notebook
# 13                                                 cd
# 14                                              mkdir
# 15                                                 ls
# 16                                                NaN
# 17                                                 cd
# 18  ls, it's been the most useful command so far a...
# 19                                 Don't have one yet

# %%
data_df['How_old_are_you?'].mask(data_df['How_old_are_you?'] == '18 years old', '18', inplace=True)
data_df['How_old_are_you?'].mask(data_df['How_old_are_you?'] == '19 turning 20 on February 28', '19', inplace=True)
data_df['How_old_are_you?'].mask(data_df['How_old_are_you?'] == 'NaN', 'Did not Respond', inplace=True)
data_df['How_old_are_you?'].mask(data_df['How_old_are_you?'] == '5+', '5', inplace=True)
data_df.fillna(0, inplace = True)

data_df.head(22)
# Out:
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/2251623858.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_old_are_you?'].mask(data_df['How_old_are_you?'] == '18 years old', '18', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/2251623858.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_old_are_you?'].mask(data_df['How_old_are_you?'] == '19 turning 20 on February 28', '19', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/2251623858.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_old_are_you?'].mask(data_df['How_old_are_you?'] == 'NaN', 'Did not Respond', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/2251623858.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_old_are_you?'].mask(data_df['How_old_are_you?'] == '5+', '5', inplace=True)
#                      Timestamp   What_is_your_name?  \
# 0    2024/01/29 6:34:23 PM CST        Gavin Edwards
# 1    2024/01/29 6:46:07 PM CST                    0
# 2    2024/01/29 7:45:39 PM CST          Connor Love
# 3    2024/01/29 7:47:12 PM CST                 Liam
# 4   2024/01/29 10:45:38 PM CST    Aarushi Choudhary
# 5   2024/01/29 10:55:40 PM CST           Noel Zerai
# 6   2024/01/29 11:50:50 PM CST           Kine Thiam
# 7    2024/01/30 5:24:37 PM CST      Bandar Aldhahri
# 8   2024/01/31 10:44:53 AM CST             Aida Bah
# 9    2024/01/31 6:34:07 PM CST          Kevin Patel
# 10   2024/01/31 7:18:31 PM CST          Brady Loehr
# 11   2024/01/31 7:19:58 PM CST        Wyatt Schmitz
# 12   2024/01/31 7:20:10 PM CST          Alec Arnold
# 13   2024/01/31 7:20:54 PM CST          Tori Willis
# 14   2024/01/31 7:21:43 PM CST      Giovanni Loftis
# 15   2024/01/31 7:22:36 PM CST     Nithya Bollineni
# 16   2024/01/31 7:22:58 PM CST  Jacob Montes-Sabino
# 17   2024/01/31 7:23:13 PM CST        Will Naftzger
# 18   2024/01/31 7:25:03 PM CST        Nora El-Ruwie
# 19   2024/01/31 7:25:54 PM CST        Darryl Franks
#
#    What_state/country_were_you_born_in? Are_you_working_while_in_school?  \
# 0                         Missouri, USA                              Yes
# 1                         Missouri, USA                              Yes
# 2                         Illinois, USA                               No
# 3                         Missouri, USA                              Yes
# 4                                 Japan                              Yes
# 5                         Missouri, USA                              Yes
# 6                         United States                              Yes
# 7                          Saudi Arabia                              Yes
# 8                        Minnesota, USA                              Yes
# 9                                 India                               No
# 10                        Missouri, USA                               No
# 11                      New Mexico, USA                              Yes
# 12                        Missouri, USA                               No
# 13                        Missouri, USA                              Yes
# 14                        Missouri, USA                              Yes
# 15                        Missouri, USA                               No
# 16                         Georgia, USA                               No
# 17                        Illinois, USA                              Yes
# 18                      Benghazi, Libya                              Yes
# 19                        Missouri, USA                               No
#
#    How_much_experience_do_you_have_programming? What_class_are_you_in?_  \
# 0                             6 months - 1 year                Freshman
# 1                                    0-3 months                Freshman
# 2                                    0-3 months                Freshman
# 3                                    0-3 months                Freshman
# 4                                    0-3 months                Freshman
# 5                                    0-3 months                Freshman
# 6                                    0-3 months                Freshman
# 7                                    0-3 months                  Junior
# 8                                    0-3 months                Freshman
# 9                                    0-3 months                  Senior
# 10                                   0-3 months               Sophomore
# 11                                   0-3 months                Freshman
# 12                                   4-6 months                Freshman
# 13                                    1-2 years               Sophomore
# 14                                   0-3 months               Sophomore
# 15                                   0-3 months                Freshman
# 16                                   0-3 months                  Junior
# 17                                   0-3 months               Sophomore
# 18                                   0-3 months                Freshman
# 19                            6 months - 1 year                Freshman
#
#    How_many_siblings_do_you_have?  \
# 0                               1
# 1                               2
# 2                               1
# 3                               1
# 4                               1
# 5                               2
# 6                              5+
# 7                              5+
# 8                               2
# 9                               0
# 10                              1
# 11                              1
# 12                              1
# 13                             5+
# 14                              4
# 15                              1
# 16                              2
# 17                              2
# 18                              3
# 19                              2
#
#          How_many_pets_and_of_which_kind_do_you_have?  \
# 0               I have two dogs both chihuahua mixes.
# 1                                                   0
# 2   I have two golden retrievers, Ellie and Amber....
# 3                                                   0
# 4                                             No pets
# 5                                                none
# 6                                                   0
# 7                                                   0
# 8                                                   0
# 9                                                   0
# 10                     We have a Husky named Maverick
# 11                                            None ):
# 12                          2 miniature daschund dogs
# 13                                               none
# 14                                         1 Maincoon
# 15                                                  0
# 16                                                  0
# 17  My french bulldog just passed away a few month...
# 18                                  2 cats and 1 dog
# 19                                           No pets
#
#             What_is_your_favorite_type_of_food? Where_do_you_live?  \
# 0             Pasta but fish is a close second.          On campus
# 1                                     Hot wings         Off campus
# 2                                      Mexican.          On campus
# 3                                    Vietnamese         Off campus
# 4                                         Pasta          On campus
# 5                                        injera          On campus
# 6                                     PASTAAAAA          On campus
# 7                                        Kabsa          Off campus
# 8                                  Gambian Food          On campus
# 9                                       Italian         Off campus
# 10  some sort of steak, probably a filet mignon          On campus
# 11                        Burgers (blue cheese)         Off campus
# 12                              grilled chicken          On campus
# 13                                        pasta         Off campus
# 14                                       salmon         Off campus
# 15                      I don't have a favorite          On campus
# 16                                        Pasta         Off campus
# 17                         mexican/middleastern          On campus
# 18                                     Brownies         Off campus
# 19                               Pizza or Steak          On campus
#
#    Do_you_take_the_metro?                                What_is_your_major?  \
# 0                      No                                      Data Science
# 1                      No                                            Nursing
# 2                      No                             Economics and Finance.
# 3                      No                                       Biochemistry
# 4                     Yes                                    Health Sciences
# 5                      No                                           comp sci
# 6                     Yes  It was pre medicine therefore biology but I de...
# 7                      No  Criminology and Criminal Justice and I am plan...
# 8                     Yes                                   Computer Science
# 9                      No                                            Finance
# 10                     No                                        Mathematics
# 11                     No                 International Business (Graduated)
# 12                     No                                   computer science
# 13                     No                                   Computer Science
# 14                     No                                       data science
# 15                     No                                   Forensic Science
# 16                     No                                   Computer Science
# 17                    Yes                                       Data Science
# 18                     No                                  Computer Science
# 19                     No                                       Computer Sci
#
#    How_old_are_you?                     What_is_your_favorite_TV_show?  \
# 0                18                                       Breaking Bad
# 1                19                                     Criminal Minds
# 2                19                                          The Wire.
# 3                18                                                  0
# 4                18                                                  0
# 5                19                                        on my block
# 6                18                                              Reign
# 7                 0                                       Breaking Bad
# 8                18                                                  0
# 9                21                                     Peaky Blinders
# 10               19  all time: How to Get Away with Murder. still r...
# 11               22                                  Better Call Saul
# 12               18                                       black mirror
# 13               19                              Nothing at the moment
# 14               20                                            Atlanta
# 15               18                                     I can't choose
# 16               21                              How I Met Your Mother
# 17               19                                       Breaking Bad
# 18               18                                             Reign
# 19               18                                The Vampire Diaries
#
#    What_is_your_favorite_video_game?  \
# 0                      Rocket League
# 1                           Valorant
# 2                   Pokémon White 2.
# 3                                  0
# 4                        Spiderman 2
# 5            assassins creed origins
# 6                       It takes two
# 7                     FIFA - Soccer
# 8                                  0
# 9                            Warzone
# 10                  currently Madden
# 11               Super Mario Galaxy
# 12                          valorant
# 13                       Predecessor
# 14                 fallout new Vegas
# 15                          Fortnite
# 16                              FIFA
# 17                        The Finals
# 18                          The Sims
# 19                   Any Nba 2k game
#
#                           What_is_your_favorite_book?  \
# 0                                   The Scythe series
# 1                    A Little life by Hanya Yanaghara
# 2                  "Surprised by Joy" by C. S. Lewis.
# 3                                                   0
# 4                                                   0
# 5                                         kite runner
# 6                                              Wonder
# 7                                                   0
# 8                Dead End Memories - Banana Yoshimoto
# 9                                    The Great Gatsby
# 10  haven't read for fun in years but the I am Num...
# 11                        The Man in the High Castle
# 12                                            catch22
# 13                              Nothing at the moment
# 14                                           catch 22
# 15                             Karen M. McManus books
# 16              Harry Potter and the Sorcerer's Stone
# 17                                               Wool
# 18        The Throne of Glass series by Sarah J. Maas
# 19                  Percy Jackson the lighting thief
#
#                       Why_are_you_taking_this_class?_  \
# 0       Its a requirement for the data science major.
# 1   I have an interest in programming. I enjoy lea...
# 2   Transfer course requirements for the Universit...
# 3                                       Applicability
# 4           I'm trying to get a minor in data science
# 5              just as an intro to my desired career.
# 6   At first it was to see if I’d like computer sc...
# 7   I am planing to get a master degree in CyberSe...
# 8                      For my major, to learn python
# 9   To learn the basics of python to help me stand...
# 10                     data science minor requirement
# 11  Foundation in Computer Science. I want to expa...
# 12                                   credit for major
# 13                  I want to be a better programmer.
# 14                                           required
# 15  For my minor and as a backup for a potential c...
# 16                                  Major requirement
# 17                         I need it for data science
# 18  To start building a foundation in code, especi...
# 19  I want to be able to do my major. Started of w...
#
#                     Whats_your_favorite_bash_command?
# 0                                                  ls
# 1                                                   0
# 2                  <git push> by far, too satisfying.
# 3                                                   0
# 4                                                  ls
# 5                                                ls
# 6                                                   0
# 7                                   until  now is pwd
# 8                                                tree
# 9                                                'cd'
# 10                                   jupyter notebook
# 11                                                  0
# 12                                   jupyter notebook
# 13                                                 cd
# 14                                              mkdir
# 15                                                 ls
# 16                                                  0
# 17                                                 cd
# 18  ls, it's been the most useful command so far a...
# 19                                 Don't have one yet

# %%
data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == '0', 'No pets', inplace=True)
data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == 'no pets', 'No pets', inplace=True)
data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == 'None ):', 'No pets', inplace=True)
data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == 'none', 'No pets', inplace=True)
data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == 'I have two dogs both chihuahua mixes.', 'Two dogs', inplace=True)
data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == 'I have two golden retrievers, Ellie and Amber. Ellie is ten years young and everything good about life. Amber is two and scared of everything (foster), but Ellie\'s teaching her that things—even plastic bags—are okay.', 'Two dogs', inplace=True)
data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == 'We have a Husky named Maverick', 'One dog', inplace=True)
data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == '2 miniature daschund dogs', 'Two dogs', inplace=True)
data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == '1 Maincoon', 'One cat', inplace=True)
data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == '2 cats and 1 dog', 'Two Cats and one dog', inplace=True)
data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == 'My french bulldog just passed away a few months ago', 'No pets', inplace=True)




data_df.head(22)
# Out:
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/67635844.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == '0', 'No pets', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/67635844.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == 'no pets', 'No pets', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/67635844.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == 'None ):', 'No pets', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/67635844.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == 'none', 'No pets', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/67635844.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == 'I have two dogs both chihuahua mixes.', 'Two dogs', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/67635844.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == 'I have two golden retrievers, Ellie and Amber. Ellie is ten years young and everything good about life. Amber is two and scared of everything (foster), but Ellie\'s teaching her that things—even plastic bags—are okay.', 'Two dogs', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/67635844.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == 'We have a Husky named Maverick', 'One dog', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/67635844.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == '2 miniature daschund dogs', 'Two dogs', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/67635844.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == '1 Maincoon', 'One cat', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/67635844.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == '2 cats and 1 dog', 'Two Cats and one dog', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/67635844.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['How_many_pets_and_of_which_kind_do_you_have?'].mask(data_df['How_many_pets_and_of_which_kind_do_you_have?'] == 'My french bulldog just passed away a few months ago', 'No pets', inplace=True)
#                      Timestamp   What_is_your_name?  \
# 0    2024/01/29 6:34:23 PM CST        Gavin Edwards
# 1    2024/01/29 6:46:07 PM CST                    0
# 2    2024/01/29 7:45:39 PM CST          Connor Love
# 3    2024/01/29 7:47:12 PM CST                 Liam
# 4   2024/01/29 10:45:38 PM CST    Aarushi Choudhary
# 5   2024/01/29 10:55:40 PM CST           Noel Zerai
# 6   2024/01/29 11:50:50 PM CST           Kine Thiam
# 7    2024/01/30 5:24:37 PM CST      Bandar Aldhahri
# 8   2024/01/31 10:44:53 AM CST             Aida Bah
# 9    2024/01/31 6:34:07 PM CST          Kevin Patel
# 10   2024/01/31 7:18:31 PM CST          Brady Loehr
# 11   2024/01/31 7:19:58 PM CST        Wyatt Schmitz
# 12   2024/01/31 7:20:10 PM CST          Alec Arnold
# 13   2024/01/31 7:20:54 PM CST          Tori Willis
# 14   2024/01/31 7:21:43 PM CST      Giovanni Loftis
# 15   2024/01/31 7:22:36 PM CST     Nithya Bollineni
# 16   2024/01/31 7:22:58 PM CST  Jacob Montes-Sabino
# 17   2024/01/31 7:23:13 PM CST        Will Naftzger
# 18   2024/01/31 7:25:03 PM CST        Nora El-Ruwie
# 19   2024/01/31 7:25:54 PM CST        Darryl Franks
#
#    What_state/country_were_you_born_in? Are_you_working_while_in_school?  \
# 0                         Missouri, USA                              Yes
# 1                         Missouri, USA                              Yes
# 2                         Illinois, USA                               No
# 3                         Missouri, USA                              Yes
# 4                                 Japan                              Yes
# 5                         Missouri, USA                              Yes
# 6                         United States                              Yes
# 7                          Saudi Arabia                              Yes
# 8                        Minnesota, USA                              Yes
# 9                                 India                               No
# 10                        Missouri, USA                               No
# 11                      New Mexico, USA                              Yes
# 12                        Missouri, USA                               No
# 13                        Missouri, USA                              Yes
# 14                        Missouri, USA                              Yes
# 15                        Missouri, USA                               No
# 16                         Georgia, USA                               No
# 17                        Illinois, USA                              Yes
# 18                      Benghazi, Libya                              Yes
# 19                        Missouri, USA                               No
#
#    How_much_experience_do_you_have_programming? What_class_are_you_in?_  \
# 0                             6 months - 1 year                Freshman
# 1                                    0-3 months                Freshman
# 2                                    0-3 months                Freshman
# 3                                    0-3 months                Freshman
# 4                                    0-3 months                Freshman
# 5                                    0-3 months                Freshman
# 6                                    0-3 months                Freshman
# 7                                    0-3 months                  Junior
# 8                                    0-3 months                Freshman
# 9                                    0-3 months                  Senior
# 10                                   0-3 months               Sophomore
# 11                                   0-3 months                Freshman
# 12                                   4-6 months                Freshman
# 13                                    1-2 years               Sophomore
# 14                                   0-3 months               Sophomore
# 15                                   0-3 months                Freshman
# 16                                   0-3 months                  Junior
# 17                                   0-3 months               Sophomore
# 18                                   0-3 months                Freshman
# 19                            6 months - 1 year                Freshman
#
#    How_many_siblings_do_you_have?  \
# 0                               1
# 1                               2
# 2                               1
# 3                               1
# 4                               1
# 5                               2
# 6                              5+
# 7                              5+
# 8                               2
# 9                               0
# 10                              1
# 11                              1
# 12                              1
# 13                             5+
# 14                              4
# 15                              1
# 16                              2
# 17                              2
# 18                              3
# 19                              2
#
#    How_many_pets_and_of_which_kind_do_you_have?  \
# 0                                      Two dogs
# 1                                       No pets
# 2                                      Two dogs
# 3                                       No pets
# 4                                       No pets
# 5                                       No pets
# 6                                       No pets
# 7                                       No pets
# 8                                       No pets
# 9                                             0
# 10                                      One dog
# 11                                      No pets
# 12                                     Two dogs
# 13                                      No pets
# 14                                      One cat
# 15                                            0
# 16                                      No pets
# 17                                      No pets
# 18                            2 cats and 1 dog
# 19                                     No pets
#
#             What_is_your_favorite_type_of_food? Where_do_you_live?  \
# 0             Pasta but fish is a close second.          On campus
# 1                                     Hot wings         Off campus
# 2                                      Mexican.          On campus
# 3                                    Vietnamese         Off campus
# 4                                         Pasta          On campus
# 5                                        injera          On campus
# 6                                     PASTAAAAA          On campus
# 7                                        Kabsa          Off campus
# 8                                  Gambian Food          On campus
# 9                                       Italian         Off campus
# 10  some sort of steak, probably a filet mignon          On campus
# 11                        Burgers (blue cheese)         Off campus
# 12                              grilled chicken          On campus
# 13                                        pasta         Off campus
# 14                                       salmon         Off campus
# 15                      I don't have a favorite          On campus
# 16                                        Pasta         Off campus
# 17                         mexican/middleastern          On campus
# 18                                     Brownies         Off campus
# 19                               Pizza or Steak          On campus
#
#    Do_you_take_the_metro?                                What_is_your_major?  \
# 0                      No                                      Data Science
# 1                      No                                            Nursing
# 2                      No                             Economics and Finance.
# 3                      No                                       Biochemistry
# 4                     Yes                                    Health Sciences
# 5                      No                                           comp sci
# 6                     Yes  It was pre medicine therefore biology but I de...
# 7                      No  Criminology and Criminal Justice and I am plan...
# 8                     Yes                                   Computer Science
# 9                      No                                            Finance
# 10                     No                                        Mathematics
# 11                     No                 International Business (Graduated)
# 12                     No                                   computer science
# 13                     No                                   Computer Science
# 14                     No                                       data science
# 15                     No                                   Forensic Science
# 16                     No                                   Computer Science
# 17                    Yes                                       Data Science
# 18                     No                                  Computer Science
# 19                     No                                       Computer Sci
#
#    How_old_are_you?                     What_is_your_favorite_TV_show?  \
# 0                18                                       Breaking Bad
# 1                19                                     Criminal Minds
# 2                19                                          The Wire.
# 3                18                                                  0
# 4                18                                                  0
# 5                19                                        on my block
# 6                18                                              Reign
# 7                 0                                       Breaking Bad
# 8                18                                                  0
# 9                21                                     Peaky Blinders
# 10               19  all time: How to Get Away with Murder. still r...
# 11               22                                  Better Call Saul
# 12               18                                       black mirror
# 13               19                              Nothing at the moment
# 14               20                                            Atlanta
# 15               18                                     I can't choose
# 16               21                              How I Met Your Mother
# 17               19                                       Breaking Bad
# 18               18                                             Reign
# 19               18                                The Vampire Diaries
#
#    What_is_your_favorite_video_game?  \
# 0                      Rocket League
# 1                           Valorant
# 2                   Pokémon White 2.
# 3                                  0
# 4                        Spiderman 2
# 5            assassins creed origins
# 6                       It takes two
# 7                     FIFA - Soccer
# 8                                  0
# 9                            Warzone
# 10                  currently Madden
# 11               Super Mario Galaxy
# 12                          valorant
# 13                       Predecessor
# 14                 fallout new Vegas
# 15                          Fortnite
# 16                              FIFA
# 17                        The Finals
# 18                          The Sims
# 19                   Any Nba 2k game
#
#                           What_is_your_favorite_book?  \
# 0                                   The Scythe series
# 1                    A Little life by Hanya Yanaghara
# 2                  "Surprised by Joy" by C. S. Lewis.
# 3                                                   0
# 4                                                   0
# 5                                         kite runner
# 6                                              Wonder
# 7                                                   0
# 8                Dead End Memories - Banana Yoshimoto
# 9                                    The Great Gatsby
# 10  haven't read for fun in years but the I am Num...
# 11                        The Man in the High Castle
# 12                                            catch22
# 13                              Nothing at the moment
# 14                                           catch 22
# 15                             Karen M. McManus books
# 16              Harry Potter and the Sorcerer's Stone
# 17                                               Wool
# 18        The Throne of Glass series by Sarah J. Maas
# 19                  Percy Jackson the lighting thief
#
#                       Why_are_you_taking_this_class?_  \
# 0       Its a requirement for the data science major.
# 1   I have an interest in programming. I enjoy lea...
# 2   Transfer course requirements for the Universit...
# 3                                       Applicability
# 4           I'm trying to get a minor in data science
# 5              just as an intro to my desired career.
# 6   At first it was to see if I’d like computer sc...
# 7   I am planing to get a master degree in CyberSe...
# 8                      For my major, to learn python
# 9   To learn the basics of python to help me stand...
# 10                     data science minor requirement
# 11  Foundation in Computer Science. I want to expa...
# 12                                   credit for major
# 13                  I want to be a better programmer.
# 14                                           required
# 15  For my minor and as a backup for a potential c...
# 16                                  Major requirement
# 17                         I need it for data science
# 18  To start building a foundation in code, especi...
# 19  I want to be able to do my major. Started of w...
#
#                     Whats_your_favorite_bash_command?
# 0                                                  ls
# 1                                                   0
# 2                  <git push> by far, too satisfying.
# 3                                                   0
# 4                                                  ls
# 5                                                ls
# 6                                                   0
# 7                                   until  now is pwd
# 8                                                tree
# 9                                                'cd'
# 10                                   jupyter notebook
# 11                                                  0
# 12                                   jupyter notebook
# 13                                                 cd
# 14                                              mkdir
# 15                                                 ls
# 16                                                  0
# 17                                                 cd
# 18  ls, it's been the most useful command so far a...
# 19                                 Don't have one yet

# %%
data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'computer science', 'Computer Science', inplace=True)
data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'Economics and Finance.', 'Economics and Finance', inplace=True)
data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'data science', 'Data Science', inplace=True)
data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'International Business (Graduated)', 'International Business', inplace=True)
data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'comp sci', 'Computer Science', inplace=True)
data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'It was pre medicine therefore biology but I decided to switch over to computer science because I did not want to endure the tedious amounts of schooling to be a physician and I find software programming to be cool and the future.', 'Computer Science', inplace=True)
data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'Criminology and Criminal Justice and I am planing to have a minor in CS', 'Criminology', inplace=True)
data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'Computer Sci', 'Computer Science', inplace=True)

data_df.head(22)
# Out:
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/2553075025.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'computer science', 'Computer Science', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/2553075025.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'Economics and Finance.', 'Economics and Finance', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/2553075025.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'data science', 'Data Science', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/2553075025.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'International Business (Graduated)', 'International Business', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/2553075025.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'comp sci', 'Computer Science', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/2553075025.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'It was pre medicine therefore biology but I decided to switch over to computer science because I did not want to endure the tedious amounts of schooling to be a physician and I find software programming to be cool and the future.', 'Computer Science', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/2553075025.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'Criminology and Criminal Justice and I am planing to have a minor in CS', 'Criminology', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/2553075025.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_major?'].mask(data_df['What_is_your_major?'] == 'Computer Sci', 'Computer Science', inplace=True)
#                      Timestamp   What_is_your_name?  \
# 0    2024/01/29 6:34:23 PM CST        Gavin Edwards
# 1    2024/01/29 6:46:07 PM CST                    0
# 2    2024/01/29 7:45:39 PM CST          Connor Love
# 3    2024/01/29 7:47:12 PM CST                 Liam
# 4   2024/01/29 10:45:38 PM CST    Aarushi Choudhary
# 5   2024/01/29 10:55:40 PM CST           Noel Zerai
# 6   2024/01/29 11:50:50 PM CST           Kine Thiam
# 7    2024/01/30 5:24:37 PM CST      Bandar Aldhahri
# 8   2024/01/31 10:44:53 AM CST             Aida Bah
# 9    2024/01/31 6:34:07 PM CST          Kevin Patel
# 10   2024/01/31 7:18:31 PM CST          Brady Loehr
# 11   2024/01/31 7:19:58 PM CST        Wyatt Schmitz
# 12   2024/01/31 7:20:10 PM CST          Alec Arnold
# 13   2024/01/31 7:20:54 PM CST          Tori Willis
# 14   2024/01/31 7:21:43 PM CST      Giovanni Loftis
# 15   2024/01/31 7:22:36 PM CST     Nithya Bollineni
# 16   2024/01/31 7:22:58 PM CST  Jacob Montes-Sabino
# 17   2024/01/31 7:23:13 PM CST        Will Naftzger
# 18   2024/01/31 7:25:03 PM CST        Nora El-Ruwie
# 19   2024/01/31 7:25:54 PM CST        Darryl Franks
#
#    What_state/country_were_you_born_in? Are_you_working_while_in_school?  \
# 0                         Missouri, USA                              Yes
# 1                         Missouri, USA                              Yes
# 2                         Illinois, USA                               No
# 3                         Missouri, USA                              Yes
# 4                                 Japan                              Yes
# 5                         Missouri, USA                              Yes
# 6                         United States                              Yes
# 7                          Saudi Arabia                              Yes
# 8                        Minnesota, USA                              Yes
# 9                                 India                               No
# 10                        Missouri, USA                               No
# 11                      New Mexico, USA                              Yes
# 12                        Missouri, USA                               No
# 13                        Missouri, USA                              Yes
# 14                        Missouri, USA                              Yes
# 15                        Missouri, USA                               No
# 16                         Georgia, USA                               No
# 17                        Illinois, USA                              Yes
# 18                      Benghazi, Libya                              Yes
# 19                        Missouri, USA                               No
#
#    How_much_experience_do_you_have_programming? What_class_are_you_in?_  \
# 0                             6 months - 1 year                Freshman
# 1                                    0-3 months                Freshman
# 2                                    0-3 months                Freshman
# 3                                    0-3 months                Freshman
# 4                                    0-3 months                Freshman
# 5                                    0-3 months                Freshman
# 6                                    0-3 months                Freshman
# 7                                    0-3 months                  Junior
# 8                                    0-3 months                Freshman
# 9                                    0-3 months                  Senior
# 10                                   0-3 months               Sophomore
# 11                                   0-3 months                Freshman
# 12                                   4-6 months                Freshman
# 13                                    1-2 years               Sophomore
# 14                                   0-3 months               Sophomore
# 15                                   0-3 months                Freshman
# 16                                   0-3 months                  Junior
# 17                                   0-3 months               Sophomore
# 18                                   0-3 months                Freshman
# 19                            6 months - 1 year                Freshman
#
#    How_many_siblings_do_you_have?  \
# 0                               1
# 1                               2
# 2                               1
# 3                               1
# 4                               1
# 5                               2
# 6                              5+
# 7                              5+
# 8                               2
# 9                               0
# 10                              1
# 11                              1
# 12                              1
# 13                             5+
# 14                              4
# 15                              1
# 16                              2
# 17                              2
# 18                              3
# 19                              2
#
#    How_many_pets_and_of_which_kind_do_you_have?  \
# 0                                      Two dogs
# 1                                       No pets
# 2                                      Two dogs
# 3                                       No pets
# 4                                       No pets
# 5                                       No pets
# 6                                       No pets
# 7                                       No pets
# 8                                       No pets
# 9                                             0
# 10                                      One dog
# 11                                      No pets
# 12                                     Two dogs
# 13                                      No pets
# 14                                      One cat
# 15                                            0
# 16                                      No pets
# 17                                      No pets
# 18                            2 cats and 1 dog
# 19                                     No pets
#
#             What_is_your_favorite_type_of_food? Where_do_you_live?  \
# 0             Pasta but fish is a close second.          On campus
# 1                                     Hot wings         Off campus
# 2                                      Mexican.          On campus
# 3                                    Vietnamese         Off campus
# 4                                         Pasta          On campus
# 5                                        injera          On campus
# 6                                     PASTAAAAA          On campus
# 7                                        Kabsa          Off campus
# 8                                  Gambian Food          On campus
# 9                                       Italian         Off campus
# 10  some sort of steak, probably a filet mignon          On campus
# 11                        Burgers (blue cheese)         Off campus
# 12                              grilled chicken          On campus
# 13                                        pasta         Off campus
# 14                                       salmon         Off campus
# 15                      I don't have a favorite          On campus
# 16                                        Pasta         Off campus
# 17                         mexican/middleastern          On campus
# 18                                     Brownies         Off campus
# 19                               Pizza or Steak          On campus
#
#    Do_you_take_the_metro?     What_is_your_major? How_old_are_you?  \
# 0                      No           Data Science                18
# 1                      No                 Nursing               19
# 2                      No   Economics and Finance               19
# 3                      No            Biochemistry               18
# 4                     Yes         Health Sciences               18
# 5                      No        Computer Science               19
# 6                     Yes        Computer Science               18
# 7                      No             Criminology                0
# 8                     Yes        Computer Science               18
# 9                      No                 Finance               21
# 10                     No             Mathematics               19
# 11                     No  International Business               22
# 12                     No        Computer Science               18
# 13                     No        Computer Science               19
# 14                     No            Data Science               20
# 15                     No        Forensic Science               18
# 16                     No        Computer Science               21
# 17                    Yes            Data Science               19
# 18                     No       Computer Science                18
# 19                     No        Computer Science               18
#
#                        What_is_your_favorite_TV_show?  \
# 0                                        Breaking Bad
# 1                                      Criminal Minds
# 2                                           The Wire.
# 3                                                   0
# 4                                                   0
# 5                                         on my block
# 6                                               Reign
# 7                                        Breaking Bad
# 8                                                   0
# 9                                      Peaky Blinders
# 10  all time: How to Get Away with Murder. still r...
# 11                                  Better Call Saul
# 12                                       black mirror
# 13                              Nothing at the moment
# 14                                            Atlanta
# 15                                     I can't choose
# 16                              How I Met Your Mother
# 17                                       Breaking Bad
# 18                                             Reign
# 19                                The Vampire Diaries
#
#    What_is_your_favorite_video_game?  \
# 0                      Rocket League
# 1                           Valorant
# 2                   Pokémon White 2.
# 3                                  0
# 4                        Spiderman 2
# 5            assassins creed origins
# 6                       It takes two
# 7                     FIFA - Soccer
# 8                                  0
# 9                            Warzone
# 10                  currently Madden
# 11               Super Mario Galaxy
# 12                          valorant
# 13                       Predecessor
# 14                 fallout new Vegas
# 15                          Fortnite
# 16                              FIFA
# 17                        The Finals
# 18                          The Sims
# 19                   Any Nba 2k game
#
#                           What_is_your_favorite_book?  \
# 0                                   The Scythe series
# 1                    A Little life by Hanya Yanaghara
# 2                  "Surprised by Joy" by C. S. Lewis.
# 3                                                   0
# 4                                                   0
# 5                                         kite runner
# 6                                              Wonder
# 7                                                   0
# 8                Dead End Memories - Banana Yoshimoto
# 9                                    The Great Gatsby
# 10  haven't read for fun in years but the I am Num...
# 11                        The Man in the High Castle
# 12                                            catch22
# 13                              Nothing at the moment
# 14                                           catch 22
# 15                             Karen M. McManus books
# 16              Harry Potter and the Sorcerer's Stone
# 17                                               Wool
# 18        The Throne of Glass series by Sarah J. Maas
# 19                  Percy Jackson the lighting thief
#
#                       Why_are_you_taking_this_class?_  \
# 0       Its a requirement for the data science major.
# 1   I have an interest in programming. I enjoy lea...
# 2   Transfer course requirements for the Universit...
# 3                                       Applicability
# 4           I'm trying to get a minor in data science
# 5              just as an intro to my desired career.
# 6   At first it was to see if I’d like computer sc...
# 7   I am planing to get a master degree in CyberSe...
# 8                      For my major, to learn python
# 9   To learn the basics of python to help me stand...
# 10                     data science minor requirement
# 11  Foundation in Computer Science. I want to expa...
# 12                                   credit for major
# 13                  I want to be a better programmer.
# 14                                           required
# 15  For my minor and as a backup for a potential c...
# 16                                  Major requirement
# 17                         I need it for data science
# 18  To start building a foundation in code, especi...
# 19  I want to be able to do my major. Started of w...
#
#                     Whats_your_favorite_bash_command?
# 0                                                  ls
# 1                                                   0
# 2                  <git push> by far, too satisfying.
# 3                                                   0
# 4                                                  ls
# 5                                                ls
# 6                                                   0
# 7                                   until  now is pwd
# 8                                                tree
# 9                                                'cd'
# 10                                   jupyter notebook
# 11                                                  0
# 12                                   jupyter notebook
# 13                                                 cd
# 14                                              mkdir
# 15                                                 ls
# 16                                                  0
# 17                                                 cd
# 18  ls, it's been the most useful command so far a...
# 19                                 Don't have one yet

# %%
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'Pasta but fish is a close second.', 'Pasta', inplace=True)
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'Mexican.', 'Mexican', inplace=True)
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'PASTAAAAA', 'Pasta', inplace=True)
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'some sort of steak, probably a filet mignon', 'Steak', inplace=True)
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'Burgers (blue cheese)', 'Burgers', inplace=True)
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'grilled chicken', 'Grilled Chicken', inplace=True)
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'Burgers (blue cheese)', 'Burgers', inplace=True)
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'pasta', 'Pasta', inplace=True)
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'salmon', 'Salmon', inplace=True)
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'I don\'t have a favorite', 'NA', inplace=True)
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'mexican/middleastern', 'Mexican', inplace=True)
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'mexican/middleastern', 'Mexican', inplace=True)
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'salmon', 'Salmon', inplace=True)
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'Steak', 'Steak', inplace=True)
data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'injera', 'Injera', inplace=True)

data_df.head(22)
# Out:
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'Pasta but fish is a close second.', 'Pasta', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'Mexican.', 'Mexican', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'PASTAAAAA', 'Pasta', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'some sort of steak, probably a filet mignon', 'Steak', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'Burgers (blue cheese)', 'Burgers', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'grilled chicken', 'Grilled Chicken', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'Burgers (blue cheese)', 'Burgers', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'pasta', 'Pasta', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'salmon', 'Salmon', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'I don\'t have a favorite', 'NA', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'mexican/middleastern', 'Mexican', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'mexican/middleastern', 'Mexican', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'salmon', 'Salmon', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'Steak', 'Steak', inplace=True)
# /var/folders/kq/22rtshv9635518wrmfbx3l1r0000gn/T/ipykernel_31454/3806129779.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_df['What_is_your_favorite_type_of_food?'].mask(data_df['What_is_your_favorite_type_of_food?'] == 'injera', 'Injera', inplace=True)
#                      Timestamp   What_is_your_name?  \
# 0    2024/01/29 6:34:23 PM CST        Gavin Edwards
# 1    2024/01/29 6:46:07 PM CST                    0
# 2    2024/01/29 7:45:39 PM CST          Connor Love
# 3    2024/01/29 7:47:12 PM CST                 Liam
# 4   2024/01/29 10:45:38 PM CST    Aarushi Choudhary
# 5   2024/01/29 10:55:40 PM CST           Noel Zerai
# 6   2024/01/29 11:50:50 PM CST           Kine Thiam
# 7    2024/01/30 5:24:37 PM CST      Bandar Aldhahri
# 8   2024/01/31 10:44:53 AM CST             Aida Bah
# 9    2024/01/31 6:34:07 PM CST          Kevin Patel
# 10   2024/01/31 7:18:31 PM CST          Brady Loehr
# 11   2024/01/31 7:19:58 PM CST        Wyatt Schmitz
# 12   2024/01/31 7:20:10 PM CST          Alec Arnold
# 13   2024/01/31 7:20:54 PM CST          Tori Willis
# 14   2024/01/31 7:21:43 PM CST      Giovanni Loftis
# 15   2024/01/31 7:22:36 PM CST     Nithya Bollineni
# 16   2024/01/31 7:22:58 PM CST  Jacob Montes-Sabino
# 17   2024/01/31 7:23:13 PM CST        Will Naftzger
# 18   2024/01/31 7:25:03 PM CST        Nora El-Ruwie
# 19   2024/01/31 7:25:54 PM CST        Darryl Franks
#
#    What_state/country_were_you_born_in? Are_you_working_while_in_school?  \
# 0                         Missouri, USA                              Yes
# 1                         Missouri, USA                              Yes
# 2                         Illinois, USA                               No
# 3                         Missouri, USA                              Yes
# 4                                 Japan                              Yes
# 5                         Missouri, USA                              Yes
# 6                         United States                              Yes
# 7                          Saudi Arabia                              Yes
# 8                        Minnesota, USA                              Yes
# 9                                 India                               No
# 10                        Missouri, USA                               No
# 11                      New Mexico, USA                              Yes
# 12                        Missouri, USA                               No
# 13                        Missouri, USA                              Yes
# 14                        Missouri, USA                              Yes
# 15                        Missouri, USA                               No
# 16                         Georgia, USA                               No
# 17                        Illinois, USA                              Yes
# 18                      Benghazi, Libya                              Yes
# 19                        Missouri, USA                               No
#
#    How_much_experience_do_you_have_programming? What_class_are_you_in?_  \
# 0                             6 months - 1 year                Freshman
# 1                                    0-3 months                Freshman
# 2                                    0-3 months                Freshman
# 3                                    0-3 months                Freshman
# 4                                    0-3 months                Freshman
# 5                                    0-3 months                Freshman
# 6                                    0-3 months                Freshman
# 7                                    0-3 months                  Junior
# 8                                    0-3 months                Freshman
# 9                                    0-3 months                  Senior
# 10                                   0-3 months               Sophomore
# 11                                   0-3 months                Freshman
# 12                                   4-6 months                Freshman
# 13                                    1-2 years               Sophomore
# 14                                   0-3 months               Sophomore
# 15                                   0-3 months                Freshman
# 16                                   0-3 months                  Junior
# 17                                   0-3 months               Sophomore
# 18                                   0-3 months                Freshman
# 19                            6 months - 1 year                Freshman
#
#    How_many_siblings_do_you_have?  \
# 0                               1
# 1                               2
# 2                               1
# 3                               1
# 4                               1
# 5                               2
# 6                              5+
# 7                              5+
# 8                               2
# 9                               0
# 10                              1
# 11                              1
# 12                              1
# 13                             5+
# 14                              4
# 15                              1
# 16                              2
# 17                              2
# 18                              3
# 19                              2
#
#    How_many_pets_and_of_which_kind_do_you_have?  \
# 0                                      Two dogs
# 1                                       No pets
# 2                                      Two dogs
# 3                                       No pets
# 4                                       No pets
# 5                                       No pets
# 6                                       No pets
# 7                                       No pets
# 8                                       No pets
# 9                                             0
# 10                                      One dog
# 11                                      No pets
# 12                                     Two dogs
# 13                                      No pets
# 14                                      One cat
# 15                                            0
# 16                                      No pets
# 17                                      No pets
# 18                            2 cats and 1 dog
# 19                                     No pets
#
#    What_is_your_favorite_type_of_food? Where_do_you_live?  \
# 0                                Pasta          On campus
# 1                            Hot wings         Off campus
# 2                              Mexican          On campus
# 3                           Vietnamese         Off campus
# 4                                Pasta          On campus
# 5                               Injera          On campus
# 6                                Pasta          On campus
# 7                               Kabsa          Off campus
# 8                         Gambian Food          On campus
# 9                              Italian         Off campus
# 10                               Steak          On campus
# 11                             Burgers         Off campus
# 12                     Grilled Chicken          On campus
# 13                               Pasta         Off campus
# 14                              Salmon         Off campus
# 15                                  NA          On campus
# 16                               Pasta         Off campus
# 17                             Mexican          On campus
# 18                            Brownies         Off campus
# 19                      Pizza or Steak          On campus
#
#    Do_you_take_the_metro?     What_is_your_major? How_old_are_you?  \
# 0                      No           Data Science                18
# 1                      No                 Nursing               19
# 2                      No   Economics and Finance               19
# 3                      No            Biochemistry               18
# 4                     Yes         Health Sciences               18
# 5                      No        Computer Science               19
# 6                     Yes        Computer Science               18
# 7                      No             Criminology                0
# 8                     Yes        Computer Science               18
# 9                      No                 Finance               21
# 10                     No             Mathematics               19
# 11                     No  International Business               22
# 12                     No        Computer Science               18
# 13                     No        Computer Science               19
# 14                     No            Data Science               20
# 15                     No        Forensic Science               18
# 16                     No        Computer Science               21
# 17                    Yes            Data Science               19
# 18                     No       Computer Science                18
# 19                     No        Computer Science               18
#
#                        What_is_your_favorite_TV_show?  \
# 0                                        Breaking Bad
# 1                                      Criminal Minds
# 2                                           The Wire.
# 3                                                   0
# 4                                                   0
# 5                                         on my block
# 6                                               Reign
# 7                                        Breaking Bad
# 8                                                   0
# 9                                      Peaky Blinders
# 10  all time: How to Get Away with Murder. still r...
# 11                                  Better Call Saul
# 12                                       black mirror
# 13                              Nothing at the moment
# 14                                            Atlanta
# 15                                     I can't choose
# 16                              How I Met Your Mother
# 17                                       Breaking Bad
# 18                                             Reign
# 19                                The Vampire Diaries
#
#    What_is_your_favorite_video_game?  \
# 0                      Rocket League
# 1                           Valorant
# 2                   Pokémon White 2.
# 3                                  0
# 4                        Spiderman 2
# 5            assassins creed origins
# 6                       It takes two
# 7                     FIFA - Soccer
# 8                                  0
# 9                            Warzone
# 10                  currently Madden
# 11               Super Mario Galaxy
# 12                          valorant
# 13                       Predecessor
# 14                 fallout new Vegas
# 15                          Fortnite
# 16                              FIFA
# 17                        The Finals
# 18                          The Sims
# 19                   Any Nba 2k game
#
#                           What_is_your_favorite_book?  \
# 0                                   The Scythe series
# 1                    A Little life by Hanya Yanaghara
# 2                  "Surprised by Joy" by C. S. Lewis.
# 3                                                   0
# 4                                                   0
# 5                                         kite runner
# 6                                              Wonder
# 7                                                   0
# 8                Dead End Memories - Banana Yoshimoto
# 9                                    The Great Gatsby
# 10  haven't read for fun in years but the I am Num...
# 11                        The Man in the High Castle
# 12                                            catch22
# 13                              Nothing at the moment
# 14                                           catch 22
# 15                             Karen M. McManus books
# 16              Harry Potter and the Sorcerer's Stone
# 17                                               Wool
# 18        The Throne of Glass series by Sarah J. Maas
# 19                  Percy Jackson the lighting thief
#
#                       Why_are_you_taking_this_class?_  \
# 0       Its a requirement for the data science major.
# 1   I have an interest in programming. I enjoy lea...
# 2   Transfer course requirements for the Universit...
# 3                                       Applicability
# 4           I'm trying to get a minor in data science
# 5              just as an intro to my desired career.
# 6   At first it was to see if I’d like computer sc...
# 7   I am planing to get a master degree in CyberSe...
# 8                      For my major, to learn python
# 9   To learn the basics of python to help me stand...
# 10                     data science minor requirement
# 11  Foundation in Computer Science. I want to expa...
# 12                                   credit for major
# 13                  I want to be a better programmer.
# 14                                           required
# 15  For my minor and as a backup for a potential c...
# 16                                  Major requirement
# 17                         I need it for data science
# 18  To start building a foundation in code, especi...
# 19  I want to be able to do my major. Started of w...
#
#                     Whats_your_favorite_bash_command?
# 0                                                  ls
# 1                                                   0
# 2                  <git push> by far, too satisfying.
# 3                                                   0
# 4                                                  ls
# 5                                                ls
# 6                                                   0
# 7                                   until  now is pwd
# 8                                                tree
# 9                                                'cd'
# 10                                   jupyter notebook
# 11                                                  0
# 12                                   jupyter notebook
# 13                                                 cd
# 14                                              mkdir
# 15                                                 ls
# 16                                                  0
# 17                                                 cd
# 18  ls, it's been the most useful command so far a...
# 19                                 Don't have one yet

# %%
print(data_df["Where_do_you_live?"].str.lower())
# Out:
# 0      on campus
# 1     off campus
# 2      on campus
# 3     off campus
# 4      on campus
# 5      on campus
# 6      on campus
# 7     off campus
# 8      on campus
# 9     off campus
# 10     on campus
# 11    off campus
# 12     on campus
# 13    off campus
# 14    off campus
# 15     on campus
# 16    off campus
# 17     on campus
# 18    off campus
# 19     on campus
# Name: Where_do_you_live?, dtype: object
